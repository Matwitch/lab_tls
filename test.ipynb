# %%
from crypto_helpers import *

generate_ECDSA_keys_certificate("ec_test")

# %%
[Client] Sent Finished (encrypted)
###[ TLS ]###
  type      = handshake
  version   = TLS 1.2
  len       = 80    [deciphered_len= 16]
  iv        = b'I\xd3\xb0\xe17\xa4c\x87\xe0\xa6B\xee\xe3\x0b\xde\x84'
  \msg       \
   |###[ TLS Handshake - Finished ]###
   |  msgtype   = finished
   |  msglen    = 12
   |  vdata     = b'9\xc7s\xe0X\x12j\xaa\xb0@Hc'
  mac       = b'=\r_\xf3?\xbe=\xc08\xa5\xb4\xce\xb6\x03\x13j \xea+\xea\xa9\x17\xa0\xfbtN\xc6L\xc8v\xac7'
  pad       = b'\x0f\x0f\x0f\x0f\x0f\x0f\x0f\x0f\x0f\x0f\x0f\x0f\x0f\x0f\x0f'
  padlen    = 15

# %%
clinet == sevrer
# Out:
# True

# %%
from scapy.layers.tls.crypto.suites import *
from scapy.layers.tls.crypto.pkcs1 import _tls_kx_algs
print(_tls_kx_algs)
get_algs_from_ciphersuite_name("TLS_DHE_DSS_WITH_AES_128_CBC_SHA256")
# Out:
# {'NULL': <class 'scapy.layers.tls.crypto.kx_algs.KX_NULL'>, 'SSLv2': <class 'scapy.layers.tls.crypto.kx_algs.KX_SSLv2'>, 'TLS13': <class 'scapy.layers.tls.crypto.kx_algs.KX_TLS13'>, 'RSA': <class 'scapy.layers.tls.crypto.kx_algs.KX_RSA'>, 'DHE_RSA': <class 'scapy.layers.tls.crypto.kx_algs.KX_DHE_RSA'>, 'ECDHE_RSA': <class 'scapy.layers.tls.crypto.kx_algs.KX_ECDHE_RSA'>, 'RSA_EXPORT': <class 'scapy.layers.tls.crypto.kx_algs.KX_RSA_EXPORT'>, 'DHE_RSA_EXPORT': <class 'scapy.layers.tls.crypto.kx_algs.KX_DHE_RSA_EXPORT'>, 'ECDHE_ECDSA': <class 'scapy.layers.tls.crypto.kx_algs.KX_ECDHE_ECDSA'>, 'DH_anon': <class 'scapy.layers.tls.crypto.kx_algs.KX_DH_anon'>, 'ECDH_anon': <class 'scapy.layers.tls.crypto.kx_algs.KX_ECDH_anon'>, 'DH_anon_EXPORT': <class 'scapy.layers.tls.crypto.kx_algs.KX_DH_anon_EXPORT'>}
# (None,
#  scapy.layers.tls.crypto.cipher_block.Cipher_AES_128_CBC,
#  scapy.layers.tls.crypto.h_mac.Hmac_SHA256,
#  scapy.layers.tls.crypto.hash.Hash_SHA256,
#  False)
