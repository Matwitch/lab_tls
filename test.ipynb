# %%
from crypto_helpers import *

generate_ECDSA_keys_certificate("ec_test")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 from crypto_helpers import *
# ----> 3 generate_ECDSA_keys_certificate("ec_test")
#
# File c:\Users\matki\Документи\VS Code\Crypto\lab_tls\crypto_helpers.py:77, in generate_ECDSA_keys_certificate(name, key_size)
#      71 builder = _build_x509_certificate(
#      72     issuer_name="matvii",
#      73     subject_name="petro",
#      74     valid_for=45
#      75 )
#      76 builder.public_key(private_key.public_key())
# ---> 77 certificate = builder.sign(
#      78     private_key=private_key, algorithm=hashes.SHA256(),
#      79 )
#      81 with open(f"{name}.key", "wb") as f:
#      82     f.write(private_key.private_bytes(
#      83         encoding=serialization.Encoding.PEM,
#      84         format=serialization.PrivateFormat.TraditionalOpenSSL,
# ...
